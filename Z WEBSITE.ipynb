# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>3 Brothers Mobile & Auto Repair</title>
    <style>
        /* Global Styles */
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }
        body {
            font-family: 'Arial', sans-serif;
            color: #333;
            background-color: #f7f8fa;
            line-height: 1.6;
        }

        /* Header Styles */
        header {
            background: linear-gradient(to right, #2b5876, #4e4376);
            color: white;
            text-align: center;
            padding: 2.5rem 1rem;
            font-size: 2.5rem;
            font-weight: bold;
        }

        /* Container */
        .container {
            max-width: 900px;
            margin: 2rem auto;
            padding: 1.5rem;
            background-color: #ffffff;
            box-shadow: 0px 4px 10px rgba(0, 0, 0, 0.1);
            border-radius: 8px;
        }

        /* Section Headings */
        h2 {
            color: #4e4376;
            font-size: 1.8rem;
            margin-bottom: 1rem;
            border-bottom: 2px solid #ff6600;
            padding-bottom: 0.5rem;
        }

        /* Service List */
        .service-list {
            display: grid;
            grid-template-columns: repeat(2, 1fr);
            gap: 0.5rem;
        }
        .service-list li {
            background-color: #e9ecef;
            padding: 10px;
            margin: 5px 0;
            border-radius: 5px;
            display: flex;
            align-items: center;
        }

        /* Mechanic and Contact Info */
        .contact-info, .work-hours {
            background: #f2f2f2;
            padding: 1rem;
            border-radius: 5px;
            margin-top: 1.5rem;
        }
        
        /* Call Now Button */
        .call-now {
            background: #ff6600;
            color: white;
            padding: 1rem;
            text-align: center;
            font-size: 1.2rem;
            font-weight: bold;
            border-radius: 5px;
            margin: 2rem 0;
            box-shadow: 0px 2px 6px rgba(0, 0, 0, 0.1);
        }
        .call-now a {
            color: white;
            text-decoration: none;
        }

        /* Modal Styles */
        .modal {
            display: none; 
            position: fixed; 
            z-index: 1; 
            left: 0;
            top: 0;
            width: 100%; 
            height: 100%; 
            overflow: auto; 
            background-color: rgba(0,0,0,0.4); 
            padding-top: 60px; 
        }

        .modal-content {
            background-color: #fefefe;
            margin: 5% auto; 
            padding: 20px;
            border: 1px solid #888;
            width: 80%; 
            max-width: 500px; 
            border-radius: 10px;
        }

        .close {
            color: #aaa;
            float: right;
            font-size: 28px;
            font-weight: bold;
        }

        .close:hover,
        .close:focus {
            color: black;
            text-decoration: none;
            cursor: pointer;
        }

        /* Footer */
        footer {
            text-align: center;
            padding: 1rem;
            background: #4e4376;
            color: white;
            border-radius: 0 0 8px 8px;
            font-size: 0.9rem;
        }
    </style>
</head>
<body>

<header>
    3 Brothers Mobile & Auto Repair
</header>

<div class="container">
    <h2>Our Services</h2>
    <ul class="service-list">
        <li>Battery Testing and Replacement</li>
        <li>Engine Diagnostic</li>
        <li>Transmission Diagnostic and Services</li>
        <li>Tune Up</li>
        <li>Fuel System Services</li>
        <li>Alternator Testing and Replacement</li>
        <li>Starter Replacement</li>
        <li>Steering Services</li>
        <li>Suspension Services</li>
        <li>All Brake Service</li>
        <li>Coolant System Services</li>
        <li>Valve Cover Gasket</li>
        <li>Timing Belt/Timing Change</li>
        <li>Transfer Case Service</li>
        <li>Differential Services</li>
    </ul>

    <h2>Available Mechanics</h2>
    <ul>
        <li>Zobeyr Hamidi - (303)-667-1249</li>
        <li>Omid Hamidi - (518)-366-5032</li>
        <li>Berkay Hamidi - (720)-589-3981</li>
    </ul>

    <div class="work-hours">
        <h2>Work Hours</h2>
        <p>Monday: 8 AM - 6 PM</p>
        <p>Tuesday: 8 AM - 6 PM</p>
        <p>Wednesday: 8 AM - 6 PM</p>
        <p>Thursday: 8 AM - 6 PM</p>
        <p>Friday: 8 AM - 6 PM</p>
        <p>Saturday: 9 AM - 5 PM</p>
        <p>Sunday: Closed</p>
    </div>

    <div class="contact-info">
        <h2>Contact Us</h2>
        <p>Business: (303)-667-1249</p>
        <p>Email: <a href="mailto:3brothers.mobilerepair@gmail.com">3brothers.mobilerepair@gmail.com</a></p>
    </div>

    <h2>About Us</h2>
    <p>3 Brothers Mobile & Auto Repair is a family-owned mobile automotive service dedicated to providing high-quality, convenient car care directly at your location. Founded by three brothers with a shared passion for vehicles and customer service, we specialize in a wide range of automotive repairs and maintenance, ensuring that your vehicle runs smoothly and efficiently.</p>

    <div class="call-now">
        <a href="tel:+13036671249">CALL NOW: (303)-667-1249</a>
    </div>

</div>

<!-- Modal -->
<div id="inquiryModal" class="modal">
    <div class="modal-content">
        <span class="close" id="closeModal">&times;</span>
        <h2>Inquiry Form</h2>
        <form id="inquiryForm">
            <label for="name">Name:</label><br>
            <input type="text" id="name" name="name" required><br>
            <label for="phone">Phone:</label><br>
            <input type="tel" id="phone" name="phone" required><br>
            <label for="email">Email:</label><br>
            <input type="email" id="email" name="email" required><br>
            <label for="inquiry">Inquire Regarding:</label><br>
            <textarea id="inquiry" name="inquiry" required></textarea><br><br>
            <input type="submit" value="Submit">
        </form>
    </div>
</div>

<footer>
    &copy; 2024 3 Brothers Mobile & Auto Repair
</footer>

<script>
    // Get the modal
    var modal = document.getElementById("inquiryModal");

    // Get the button that opens the modal
    window.onload = function() {
        modal.style.display = "block"; // Show the modal on page load
    }

    // Get the <span> element that closes the modal
    var span = document.getElementById("closeModal");

    // When the user clicks on <span> (x), close the modal
    span.onclick = function() {
        modal.style.display = "none";
    }

    // When the user clicks anywhere outside of the modal, close it
    window.onclick = function(event) {
        if (event.target == modal) {
            modal.style.display = "none";
        }
    }

    // Handle form submission (you can modify this part for actual form processing)
    document.getElementById("inquiryForm").onsubmit = function(event) {
        event.preventDefault(); // Prevent default form submission
        alert("Thank you for your inquiry! Our team will get back to you shortly.");
        modal.style.display = "none"; // Close modal after submission
    }
</script>

</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>3 Brothers Mobile & Auto Repair</title>
#     <style>
#         /* Global Styles */
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#         body {
#             font-family: 'Arial', sans-serif;
#             color: #333;
#             background-color: #f7f8fa;
#             line-height: 1.6;
#         }
#
#         /* Header Styles */
#         header {
#             background: linear-gradient(to right, #2b5876, #4e4376);
#             color: white;
#             text-align: center;
#             padding: 2.5rem 1rem;
#             font-size: 2.5rem;
#             font-weight: bold;
#         }
#
#         /* Container */
#         .container {
#             max-width: 900px;
#             margin: 2rem auto;
#             padding: 1.5rem;
# ...

# %%
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>3 Brothers Mobile & Auto Repair</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 20px;
            background-color: #f4f4f4;
        }
        h1, h2 {
            color: #333;
        }
        ul {
            list-style-type: none;
        }
        .contact-info {
            margin-top: 20px;
        }
    </style>
</head>
<body>
    <header>
        <h1>3 Brothers Mobile & Auto Repair</h1>
    </header>
    <div>
        <h2>Our Services</h2>
        <ul>
            <li>Battery Testing and Replacement</li>
            <li>Engine Diagnostic</li>
            <li>Transmission Diagnostic and Services</li>
            <li>Tune Up</li>
            <li>Fuel System Services</li>
            <li>Alternator Testing and Replacement</li>
            <li>Starter Replacement</li>
            <li>Steering Services</li>
            <li>Suspension Services</li>
            <li>All Brake Service</li>
            <li>Coolant System Services</li>
            <li>Valve Cover Gasket</li>
            <li>Timing Belt/Timing Chain</li>
            <li>Transfer Case Service</li>
            <li>Differential Services</li>
        </ul>
    </div>
    <div class="contact-info">
        <h2>Available Mechanics</h2>
        <ul>
            <li>Zobeyr Hamidi - (303)-667-1249</li>
            <li>Omid Hamidi - (518)-366-5032</li>
            <li>Berkay Hamidi - (720)-589-3981</li>
        </ul>
        <h2>Work Hours</h2>
        <p>Monday: 8 AM - 6 PM</p>
        <p>Tuesday: 8 AM - 6 PM</p>
        <p>Wednesday: 8 AM - 6 PM</p>
        <p>Thursday: 8 AM - 6 PM</p>
        <p>Friday: 8 AM - 6 PM</p>
        <p>Saturday: 9 AM - 5 PM</p>
        <p>Sunday: Closed</p>
        <h2>Contact Us</h2>
        <p>Business: (303)-667-1249</p>
        <p>Email: <a href="mailto:3brothers.mobilerepair@gmail.com">3brothers.mobilerepair@gmail.com</a></p>
        <h2>About Us</h2>
        <p>3 Brothers Mobile & Auto Repair is a family-owned mobile automotive service dedicated to providing high-quality, convenient car care directly at your location.</p>
    </div>
</body>
</html>
"""

# %%
# Save the HTML content to an HTML file
with open("3_brothers_mobile_auto_repair.html", "w") as file:
    file.write(html_content)

# %%
3_brothers_mobile_auto_repair.html
# Out:
#   Cell In[8], line 1
#     3_brothers_mobile_auto_repair.html
#      ^
# SyntaxError: invalid decimal literal

# %%
# Define your HTML content
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>3 Brothers Mobile & Auto Repair</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 20px;
            background-color: #f4f4f4;
        }
        h1, h2 {
            color: #333;
        }
        ul {
            list-style-type: none;
        }
        .contact-info {
            margin-top: 20px;
        }
    </style>
</head>
<body>
    <header>
        <h1>3 Brothers Mobile & Auto Repair</h1>
    </header>
    <div>
        <h2>Our Services</h2>
        <ul>
            <li>Battery Testing and Replacement</li>
            <li>Engine Diagnostic</li>
            <li>Transmission Diagnostic and Services</li>
            <li>Tune Up</li>
            <li>Fuel System Services</li>
            <li>Alternator Testing and Replacement</li>
            <li>Starter Replacement</li>
            <li>Steering Services</li>
            <li>Suspension Services</li>
            <li>All Brake Service</li>
            <li>Coolant System Services</li>
            <li>Valve Cover Gasket</li>
            <li>Timing Belt/Timing Chain</li>
            <li>Transfer Case Service</li>
            <li>Differential Services</li>
        </ul>
    </div>
    <div class="contact-info">
        <h2>Available Mechanics</h2>
        <ul>
            <li>Zobeyr Hamidi - (303)-667-1249</li>
            <li>Omid Hamidi - (518)-366-5032</li>
            <li>Berkay Hamidi - (720)-589-3981</li>
        </ul>
        <h2>Work Hours</h2>
        <p>Monday: 8 AM - 6 PM</p>
        <p>Tuesday: 8 AM - 6 PM</p>
        <p>Wednesday: 8 AM - 6 PM</p>
        <p>Thursday: 8 AM - 6 PM</p>
        <p>Friday: 8 AM - 6 PM</p>
        <p>Saturday: 9 AM - 5 PM</p>
        <p>Sunday: Closed</p>
        <h2>Contact Us</h2>
        <p>Business: (303)-667-1249</p>
        <p>Email: <a href="mailto:3brothers.mobilerepair@gmail.com">3brothers.mobilerepair@gmail.com</a></p>
        <h2>About Us</h2>
        <p>3 Brothers Mobile & Auto Repair is a family-owned mobile automotive service dedicated to providing high-quality, convenient car care directly at your location.</p>
    </div>
</body>
</html>
"""

# Save the HTML content to an HTML file
with open("3_brothers_mobile_auto_repair.html", "w") as file:
    file.write(html_content)

# %%
import os
os.listdir()  # This will list all files and folders in the current directory
# Out:
# ['.anaconda',
#  '.android',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.insomniac',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.virtual_documents',
#  '.vscode',
#  '3Bromechanic.ipynb',
#  '3bros.html',
#  '3_brothers_mobile_auto_repair.html',
#  '3_brothers_mobile_mechanic.html',
#  '656565.ipynb',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'discord-bot-env',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'Music Bot.ipynb',
#  'My Documents',
#  'mydata.dat',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{a2332f17-cdbf-11ec-8680-002248483d79}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{a2332f17-cdbf-11ec-8680-002248483d79}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{a2332f17-cdbf-11ec-8680-002248483d79}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{a2332f17-cdbf-11ec-8680-002248483d79}.TxR.blf',
# ...

# %%
os.getcwd()  # This will print the current working directory
# Out:
# 'C:\\Users\\Manan'
